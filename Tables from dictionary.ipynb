# %%
import pandas as pd

a = {'Albums': ['Thriller', 'Back in Black', 'Dark Side of the Moon', 'The Body Guard', 'Bat Out of Hell'], \
    'Length': ['00:42:19','00:42:11', '00:42:49', '00:57:44', '00:46:33'], \
    'Released':['1982', '1980','1973', '1992', '1977']}
df= pd.DataFrame(a)
df
# Out:
#                   Albums    Length Released
# 0               Thriller  00:42:19     1982
# 1          Back in Black  00:42:11     1980
# 2  Dark Side of the Moon  00:42:49     1973
# 3         The Body Guard  00:57:44     1992
# 4        Bat Out of Hell  00:46:33     1977

# %%
df.dtypes
# Out:
# Albums      object
# Length      object
# Released    object
# dtype: object

# %%
df['Albums']
# Out:
# 0                 Thriller
# 1            Back in Black
# 2    Dark Side of the Moon
# 3           The Body Guard
# 4          Bat Out of Hell
# Name: Albums, dtype: object

# %%
df.Albums
# Out:
# 0                 Thriller
# 1            Back in Black
# 2    Dark Side of the Moon
# 3           The Body Guard
# 4          Bat Out of Hell
# Name: Albums, dtype: object

# %%
df[:2]
# Out:
#           Albums    Length Released
# 0       Thriller  00:42:19     1982
# 1  Back in Black  00:42:11     1980

# %%
df['Albums'][1:4]
# Out:
# 1            Back in Black
# 2    Dark Side of the Moon
# 3           The Body Guard
# Name: Albums, dtype: object

# %%
df.head(3)
# Out:
#                   Albums    Length Released
# 0               Thriller  00:42:19     1982
# 1          Back in Black  00:42:11     1980
# 2  Dark Side of the Moon  00:42:49     1973

# %%
df['SoundTrack'] = df.Albums == 'The Body Guard'
df
# Out:
#                   Albums    Length Released  SoundTrack
# 0               Thriller  00:42:19     1982       False
# 1          Back in Black  00:42:11     1980       False
# 2  Dark Side of the Moon  00:42:49     1973       False
# 3         The Body Guard  00:57:44     1992        True
# 4        Bat Out of Hell  00:46:33     1977       False

# %%
df.loc[0]
# Out:
# Albums        Thriller
# Length        00:42:19
# Released          1982
# SoundTrack           0
# Name: 0, dtype: object

# %%
del df['SoundTrack']
df
# Out:
#                   Albums    Length Released
# 0               Thriller  00:42:19     1982
# 1          Back in Black  00:42:11     1980
# 2  Dark Side of the Moon  00:42:49     1973
# 3         The Body Guard  00:57:44     1992
# 4        Bat Out of Hell  00:46:33     1977

# %%
df.drop('Length', axis=1, inplace = True)

# %%
df
# Out:
#                                Albums Released  SoundTrack
# 0                            Thriller     1982           0
# 1                       Back in Black     1980           0
# 2               Dark Side of the Moon     1973           0
# 3                      The Body Guard     1992           1
# 4                     Bat Out of Hell     1977           0
# The Body Guard                     10       10          10

# %%
df_can1 = pd.read_excel('Canada.xlsx', sheet_name ='Canada by Citizenship',  skip_footer = 2)
print('Data read into a pandas Dataframe!')
# Out:
# Data read into a pandas Dataframe!

# %%
df_can1
# Out:
#            Type    Coverage  \
# 0    Immigrants  Foreigners
# 1    Immigrants  Foreigners
# 2    Immigrants  Foreigners
# 3    Immigrants  Foreigners
# 4    Immigrants  Foreigners
# 5    Immigrants  Foreigners
# 6    Immigrants  Foreigners
# 7    Immigrants  Foreigners
# 8    Immigrants  Foreigners
# 9    Immigrants  Foreigners
# 10   Immigrants  Foreigners
# 11   Immigrants  Foreigners
# 12   Immigrants  Foreigners
# 13   Immigrants  Foreigners
# 14   Immigrants  Foreigners
# 15   Immigrants  Foreigners
# 16   Immigrants  Foreigners
# 17   Immigrants  Foreigners
# 18   Immigrants  Foreigners
# 19   Immigrants  Foreigners
# 20   Immigrants  Foreigners
# 21   Immigrants  Foreigners
# 22   Immigrants  Foreigners
# 23   Immigrants  Foreigners
# 24   Immigrants  Foreigners
# 25   Immigrants  Foreigners
# 26   Immigrants  Foreigners
# 27   Immigrants  Foreigners
# 28   Immigrants  Foreigners
# 29   Immigrants  Foreigners
# ..          ...         ...
# 165  Immigrants  Foreigners
# ...

# %%
df_can1.drop(['AREA', 'REG', 'DEV'],axis=1,inplace=True)
df_can1.head()
# Out:
#          Type    Coverage          OdName AreaName          RegName  \
# 0  Immigrants  Foreigners     Afghanistan     Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania   Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria   Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa  Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra   Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2004  2005  2006  2007  \
# 0  Developing regions    16    39    39    47  ...  2978  3436  3009  2652
# 1   Developed regions     1     0     0     0  ...  1450  1223   856   702
# 2  Developing regions    80    67    71    69  ...  3616  3626  4807  3623
# 3  Developing regions     0     1     0     0  ...     0     0     1     0
# 4   Developed regions     0     0     0     0  ...     0     0     1     1
#
#    2008  2009  2010  2011  2012  2013
# 0  2111  1746  1758  2203  2635  2004
# ...

# %%
df_can1.rename(columns = {'OdName': 'Country', 'AreaName': 'Continent', 'RegName': 'Region'},inplace = True)
df_can1.columns
# Out:
# Index([     'Type',  'Coverage',   'Country', 'Continent',    'Region',
#          'DevName',        1980,        1981,        1982,        1983,
#               1984,        1985,        1986,        1987,        1988,
#               1989,        1990,        1991,        1992,        1993,
#               1994,        1995,        1996,        1997,        1998,
#               1999,        2000,        2001,        2002,        2003,
#               2004,        2005,        2006,        2007,        2008,
#               2009,        2010,        2011,        2012,        2013],
#       dtype='object')

# %%
df_can1['Total'] = df_can1.sum(axis=1)

# %%
df_can1.head()
# Out:
#          Type    Coverage         Country Continent           Region  \
# 0  Immigrants  Foreigners     Afghanistan      Asia    Southern Asia
# 1  Immigrants  Foreigners         Albania    Europe  Southern Europe
# 2  Immigrants  Foreigners         Algeria    Africa  Northern Africa
# 3  Immigrants  Foreigners  American Samoa   Oceania        Polynesia
# 4  Immigrants  Foreigners         Andorra    Europe  Southern Europe
#
#               DevName  1980  1981  1982  1983  ...  2005  2006  2007  2008  \
# 0  Developing regions    16    39    39    47  ...  3436  3009  2652  2111
# 1   Developed regions     1     0     0     0  ...  1223   856   702   560
# 2  Developing regions    80    67    71    69  ...  3626  4807  3623  4005
# 3  Developing regions     0     1     0     0  ...     0     1     0     0
# 4   Developed regions     0     0     0     0  ...     0     1     1     0
#
#    2009  2010  2011  2012  2013  Total
# 0  1746  1758  2203  2635  2004  58639
# ...

# %%
df_can1.loc['Total1'] = df_can1.sum(axis=0)

# %%
df_can1.tail()
# Out:
#                                                      Type  \
# 191                                            Immigrants
# 192                                            Immigrants
# 193                                            Immigrants
# 194                                            Immigrants
# Total1  ImmigrantsImmigrantsImmigrantsImmigrantsImmigr...
#
#                                                  Coverage  \
# 191                                            Foreigners
# 192                                            Foreigners
# 193                                            Foreigners
# 194                                            Foreigners
# Total1  ForeignersForeignersForeignersForeignersForeig...
#
#                                                   Country  \
# 191                                        Western Sahara
# 192                                                 Yemen
# 193                                                Zambia
# ...
