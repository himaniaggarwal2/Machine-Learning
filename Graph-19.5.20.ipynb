# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3]
y=[2,4,6]
x2=[3,4,5]
y2=[2,4,6]
plt.plot(x,y , color='b',linestyle='--')
plt.plot(x2,y2)
#plt.scatter(x,y)#to represent in dotted form
plt.show()

# %%
import numpy as np
x=np.array([1,2,3,4])
x=np.arange(0,5,0.1)# to make it look prettier
y=x**3
plt.plot(x,y)
plt.show()

# %%
sizes=[3,4,6,2]
colors=['blue','purple','red','pink']
labels=['A','B',"C",'D']
plt.title('split among clusters')
plt.pie(sizes,colors=colors,labels=labels,autopct="%.1f")
plt.show()
