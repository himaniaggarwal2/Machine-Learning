# %%
from functools import reduce

# %%
li=[5,8,19,50,100]

# %%
sum = reduce((lambda x,y:x+y), li)
print(sum)
# Out:
# 182

# %%
li=[5,54,2,6,24,5,7]
final_list= list(filter((lambda x:(x%2 !=0)),li))
print(final_list)
# Out:
# [5, 5, 7]

# %% [markdown]
# # LIST COMPREHENSION

# %%
#another method iterate krva sakta hai..it will evalutae "i*a" for i in rnage (1,11)
#final output in form of list... 
#new_list=['even if (i%2==0)']

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
print ("Matplotlib version : ", mpl.__version__)
# Out:
# Matplotlib version :  3.3.0

# %%
df_can = pd.read_excel("Canada.xlsx",sheet_name = "Canada by Citizenship")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-40478073ee20> in <module>
# ----> 1 df_can = pd.read_excel("Canada.xlsx",sheet_name = "Canada by Citizenship")
#
# /usr/local/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# ...

# %%
df_can.rename(columns = {'OdName': 'Country','AreaName' : 'Continent' , 'RegName' : 'Region'},inplace = True)

# %%
df_can.columns
# Out:
# Index([     'Type',  'Coverage',   'Country',      'AREA', 'Continent',
#              'REG',    'Region',       'DEV',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_can.set_index('Country',inplace= True)

# %%
df_can.columns= list(map(str,df_can.columns))

# %%
years = list(map(str,range(1980 , 2014)))

# %%
haiti = df_can.loc['Haiti',years]
haiti.head()
# Out:
# 1980    1666
# 1981    3692
# 1982    3498
# 1983    2860
# 1984    1418
# Name: Haiti, dtype: object

# %%
mpl.style.use(['ggplot'])
haiti.plot()

# %%
import math

# %%
import numpy as np

# %%
time = np.arange(0,10,0.1)

# %%
amp=np.sin(time)

# %%
plt.plot(time, amp)

# %%
haiti.index = haiti.index.map(int)
#change the index values of Haiti to type integer forplotting
haiti.plot(kind = 'line')
#to assign titles
plt.title('immigration from haiti')
plt.ylabel('number of immigrants')
plt.xlabel('years')
plt.text(2000,6000,'2010 earthquake')#to print something on the plot and x,yaxis 200 from x and 600from y
plt.show()

# %% [markdown]
# # Pie Chart

# %%
#grp countries by continents and apply sum() func
df_can['Total'] = df_can.sum(axis=1)
df_continents = df_can.groupby('Continent',axis=0).sum()
print(type(df_can.groupby('Continent' , axis=0)))
df_continents.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0ef878dc3a95> in <module>
#       1 #grp countries by continents and apply sum() func
# ----> 2 df_can['Total'] = df_can.sum(axis=1)
#       3 df_continents = df_can.groupby('Continent',axis=0).sum()
#       4 print(type(df_can.groupby('Continent' , axis=0)))
#       5 df_continents.head()
#
# NameError: name 'df_can' is not defined

# %%
df_continents['Total'].plot(kind='pie',
figsize=(5,6),
autopct = '%1.1f%%'
startangle=90,
shadow=True)
# Out:
#   File "<ipython-input-5-c0561c9577f0>", line 4
#     startangle=90,
#     ^
# SyntaxError: invalid syntax
